# %% [markdown]
# <a href="https://colab.research.google.com/github/Salihsarihan/Graduation_Project/blob/main/Optimization_for_mathematical_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from scipy.stats import nbinom
import openpyxl
import math
file_path = 'KZK.xlsx'
df = pd.read_excel(file_path)

# %%
data = {'Product_Name': [], 'Product_Code': [], 'v2': [], 'q2': [], 'Second_Period_Cost': []}

index = 0
while index < len(df):
    row = df.iloc[index]
    product_name = row['Product_Name']
    product_code = row['Product_Code']
    p1, p2, r1, r2 = row[['p1', 'p2', 'r1', 'r2']]
    demand1, demand2, q1_values, q2_values = row[['D1', 'D2', 'q1', 'q2']]
    v2_values = row['v2']


    v2 = 0
    while v2 <= v2_values:
        q2 = 0
        while q2 <= q2_values:
            cost_for_sec_per = 0
            d2 = 0
            while d2 <= demand2:
                D2 = nbinom.pmf(d2, r2, p2)
                cost_for_sec_per = (max((d2 - v2 - q2), 0) * D2) * 1000 + (max((v2 + q2 - d2), 0) * D2) * 1 + cost_for_sec_per
                d2 += 1
            cost_for_sec_per += q2*10
            data['Product_Name'].append(product_name)
            data['Product_Code'].append(product_code)
            data['v2'].append(v2)
            data['q2'].append(q2)
            data['Second_Period_Cost'].append(cost_for_sec_per)

            q2 += 1
        v2 += 1
    index += 1

result_rp1_output = pd.DataFrame(data)

# %%
result_rp1_output
# Out:
#                            Product_Name Product_Code  v2  q2  \
# 0    ADN_OPTIMUM_AVM,KZK,VALE,NEW_BLACK     #0200006   0   0
# 1    ADN_OPTIMUM_AVM,KZK,VALE,NEW_BLACK     #0200006   0   1
# 2    ADN_OPTIMUM_AVM,KZK,VALE,NEW_BLACK     #0200006   0   2
# 3    ADN_OPTIMUM_AVM,KZK,VALE,NEW_BLACK     #0200006   0   3
# 4    ADN_OPTIMUM_AVM,KZK,VALE,NEW_BLACK     #0200006   0   4
# ..                                  ...          ...  ..  ..
# 865  ADN_OPTIMUM_AVM,KZK,VALE,NEW_BLACK     #0200006  29  24
# 866  ADN_OPTIMUM_AVM,KZK,VALE,NEW_BLACK     #0200006  29  25
# 867  ADN_OPTIMUM_AVM,KZK,VALE,NEW_BLACK     #0200006  29  26
# 868  ADN_OPTIMUM_AVM,KZK,VALE,NEW_BLACK     #0200006  29  27
# 869  ADN_OPTIMUM_AVM,KZK,VALE,NEW_BLACK     #0200006  29  28
#
#      Second_Period_Cost
# 0           6772.942055
# 1           6175.902983
# 2           5578.891020
# 3           4982.049325
# 4           4385.925413
# ..                  ...
# 865          265.400244
# 866          276.007285
# ...

# %%
def cal_min_cost_for_sec_per(df):
    min_costs_sec_2 = df.loc[df.groupby('v2')['Second_Period_Cost'].idxmin(), ['Product_Name','v2', 'q2', 'Second_Period_Cost', ]]
    min_costs_sec_2['Product_Code'] = df['Product_Code'].iloc[0]
    # Reset index after groupby
    return min_costs_sec_2.reset_index(drop=True)

product_column = 'Product_Code'
unique_products = result_rp1_output[product_column].unique()
result_list = []

for product in unique_products:
    product_df = result_rp1_output[result_rp1_output[product_column] == product].copy()
    result = cal_min_cost_for_sec_per(product_df)
    result_list.append(result)

final_result = pd.concat(result_list)
final_result.reset_index(drop=True, inplace=True)
final_result
# Out:
#                           Product_Name  v2  q2  Second_Period_Cost  \
# 0   ADN_OPTIMUM_AVM,KZK,VALE,NEW_BLACK   0  14          141.725635
# 1   ADN_OPTIMUM_AVM,KZK,VALE,NEW_BLACK   1  13          131.725635
# 2   ADN_OPTIMUM_AVM,KZK,VALE,NEW_BLACK   2  12          121.725635
# 3   ADN_OPTIMUM_AVM,KZK,VALE,NEW_BLACK   3  11          111.725635
# 4   ADN_OPTIMUM_AVM,KZK,VALE,NEW_BLACK   4  10          101.725635
# 5   ADN_OPTIMUM_AVM,KZK,VALE,NEW_BLACK   5   9           91.725635
# 6   ADN_OPTIMUM_AVM,KZK,VALE,NEW_BLACK   6   8           81.725635
# 7   ADN_OPTIMUM_AVM,KZK,VALE,NEW_BLACK   7   7           71.725635
# 8   ADN_OPTIMUM_AVM,KZK,VALE,NEW_BLACK   8   6           61.725635
# 9   ADN_OPTIMUM_AVM,KZK,VALE,NEW_BLACK   9   5           51.725635
# 10  ADN_OPTIMUM_AVM,KZK,VALE,NEW_BLACK  10   4           41.725635
# 11  ADN_OPTIMUM_AVM,KZK,VALE,NEW_BLACK  11   3           31.725635
# 12  ADN_OPTIMUM_AVM,KZK,VALE,NEW_BLACK  12   2           21.725635
# ...

# %%
# Assuming df and final_result DataFrames are already defined

data_2 = {
    'Product_Name': [],
    'Product_Code': [],
    'v1': [],
    'q1': [],
    'Total Cost': []
}

# Iterate over rows using a for loop (preferable over while loop for clarity)
for index, row in df.iterrows():
    product_name = row['Product_Name']
    product_code = row['Product_Code']
    p1, p2, r1, r2 = row[['p1', 'p2', 'r1', 'r2']]
    demand1, q1_values, v1_values = row[['D1', 'q1', 'v1']]

    # Check and handle NaN values
    v1_values = 0 if pd.isna(v1_values) else int(v1_values)
    q1_values = 0 if pd.isna(q1_values) else int(q1_values)
    demand1 = 0 if pd.isna(demand1) else int(demand1)

    # Iterate over v1 values
    for v1 in range(v1_values + 1):
        # Iterate over q1 values
        for q1 in range(q1_values + 1):
            costdp = 0
            # Iterate over demand1 values
            for d1 in range(demand1 + 1):
                D1 = nbinom.pmf(d1, r1, p1)
                v2 = max(v1 + q1 - d1, 0)

                # Correct the condition with bitwise AND operator and parenthesis
                matching_rows = final_result.loc[(final_result['Product_Code'] == product_code) & (final_result['v2'] == v2), 'Second_Period_Cost']
                if not matching_rows.empty:
                    secondcost = matching_rows.values[0]
                else:
                    secondcost = 0  # Or set to an appropriate default value

                costdp += (5 * max(v1 + q1 - d1, 0) + 100 * max(d1 - q1 - v1, 0) + secondcost) * D1
            costdp += q1 * 10

            # Store the data for each combination
            data_2['Product_Name'].append(product_name)
            data_2['Product_Code'].append(product_code)
            data_2['v1'].append(v1)
            data_2['q1'].append(q1)
            data_2['Total Cost'].append(costdp)

# Create a DataFrame from the stored data
output_df = pd.DataFrame(data_2)

# %%
output_df
# Out:
#                            Product_Name Product_Code  v1  q1  Total Cost
# 0    ADN_OPTIMUM_AVM,KZK,VALE,NEW_BLACK     #0200006   0   0  612.705264
# 1    ADN_OPTIMUM_AVM,KZK,VALE,NEW_BLACK     #0200006   0   1  553.386728
# 2    ADN_OPTIMUM_AVM,KZK,VALE,NEW_BLACK     #0200006   0   2  494.203685
# 3    ADN_OPTIMUM_AVM,KZK,VALE,NEW_BLACK     #0200006   0   3  435.588254
# 4    ADN_OPTIMUM_AVM,KZK,VALE,NEW_BLACK     #0200006   0   4  378.574186
# ..                                  ...          ...  ..  ..         ...
# 215  ADN_OPTIMUM_AVM,KZK,VALE,NEW_BLACK     #0200006  10  15  213.650003
# 216  ADN_OPTIMUM_AVM,KZK,VALE,NEW_BLACK     #0200006  10  16  227.537638
# 217  ADN_OPTIMUM_AVM,KZK,VALE,NEW_BLACK     #0200006  10  17  241.425273
# 218  ADN_OPTIMUM_AVM,KZK,VALE,NEW_BLACK     #0200006  10  18  255.312908
# 219  ADN_OPTIMUM_AVM,KZK,VALE,NEW_BLACK     #0200006  10  19  269.200543
#
# [220 rows x 5 columns]

# %%
result = output_df.groupby(['Product_Code', 'v1']).apply(lambda x: x.loc[x['Total Cost'].idxmin()])[['Product_Code','Product_Name', 'v1', 'q1', 'Total Cost']]
result = result.reset_index(drop=True)  # Indeksi sıfırla, v1 sütununu düzelt
result['d1_range'] = result['v1'] + result['q1']

# %%
expanded_rows = []

# Her bir satır için d1_range değerini kullanarak yeni satırlar oluşturup hesaplama yapalım
for index, row in result.iterrows():
    for d1 in range(row['d1_range'] + 1):
        new_row = row.copy()
        new_row['d1'] = d1
        new_row['v2'] = row['v1'] + row['q1'] - d1
        new_row['Target_First_Period'] = row['v1'] + row['q1']

        # matching_rows DataFrame'inde ilgili satırı bulalım
        v2 = new_row['v2']
        product_code = new_row['Product_Code']
        matching_rows = final_result[(final_result['v2'] == v2) & (final_result['Product_Code'] == product_code)]

        # matching_rows'den q2 değerini alıp yeni satıra ekleyelim
        if not matching_rows.empty:
            q2 = matching_rows.iloc[0]['q2']  # Varsayılan olarak ilk eşleşen satırı alıyoruz
            new_row['q2'] = q2

        expanded_rows.append(new_row)

# Yeni DataFrame oluştur
expanded_df = pd.DataFrame(expanded_rows)
expanded_df
# Out:
#    Product_Code                        Product_Name  v1  q1  Total Cost  \
# 0      #0200006  ADN_OPTIMUM_AVM,KZK,VALE,NEW_BLACK   0  10  189.319853
# 0      #0200006  ADN_OPTIMUM_AVM,KZK,VALE,NEW_BLACK   0  10  189.319853
# 0      #0200006  ADN_OPTIMUM_AVM,KZK,VALE,NEW_BLACK   0  10  189.319853
# 0      #0200006  ADN_OPTIMUM_AVM,KZK,VALE,NEW_BLACK   0  10  189.319853
# 0      #0200006  ADN_OPTIMUM_AVM,KZK,VALE,NEW_BLACK   0  10  189.319853
# ..          ...                                 ...  ..  ..         ...
# 10     #0200006  ADN_OPTIMUM_AVM,KZK,VALE,NEW_BLACK  10   0   89.319853
# 10     #0200006  ADN_OPTIMUM_AVM,KZK,VALE,NEW_BLACK  10   0   89.319853
# 10     #0200006  ADN_OPTIMUM_AVM,KZK,VALE,NEW_BLACK  10   0   89.319853
# 10     #0200006  ADN_OPTIMUM_AVM,KZK,VALE,NEW_BLACK  10   0   89.319853
# 10     #0200006  ADN_OPTIMUM_AVM,KZK,VALE,NEW_BLACK  10   0   89.319853
#
#     d1_range  d1  v2  Target_First_Period  q2
# 0         10   0  10                   10   4
# ...

# %%
expanded_df['Target_Second_Period'] = expanded_df['v2'] + expanded_df['q2']
expanded_df = expanded_df[['Product_Name','Product_Code', 'v1', 'q1', 'Target_First_Period', 'v2', 'q2', 'Target_Second_Period']]

expanded_df
# Out:
#                           Product_Name Product_Code  v1  q1  \
# 0   ADN_OPTIMUM_AVM,KZK,VALE,NEW_BLACK     #0200006   0  10
# 0   ADN_OPTIMUM_AVM,KZK,VALE,NEW_BLACK     #0200006   0  10
# 0   ADN_OPTIMUM_AVM,KZK,VALE,NEW_BLACK     #0200006   0  10
# 0   ADN_OPTIMUM_AVM,KZK,VALE,NEW_BLACK     #0200006   0  10
# 0   ADN_OPTIMUM_AVM,KZK,VALE,NEW_BLACK     #0200006   0  10
# ..                                 ...          ...  ..  ..
# 10  ADN_OPTIMUM_AVM,KZK,VALE,NEW_BLACK     #0200006  10   0
# 10  ADN_OPTIMUM_AVM,KZK,VALE,NEW_BLACK     #0200006  10   0
# 10  ADN_OPTIMUM_AVM,KZK,VALE,NEW_BLACK     #0200006  10   0
# 10  ADN_OPTIMUM_AVM,KZK,VALE,NEW_BLACK     #0200006  10   0
# 10  ADN_OPTIMUM_AVM,KZK,VALE,NEW_BLACK     #0200006  10   0
#
#     Target_First_Period  v2  q2  Target_Second_Period
# 0                    10  10   4                    14
# 0                    10   9   5                    14
# 0                    10   8   6                    14
# ...

# %%
# 'Product_Code', 'Product_Name', 'Target_First_Period', 'Target_Second_Period' sütunlarını seçerek filtreleme
filtered_df = expanded_df[['Product_Code', 'Product_Name', 'Target_First_Period', 'Target_Second_Period']]

# 'Product_Code' sütununa göre gruplama
grouped_df = filtered_df.groupby('Product_Code').first().reset_index()

# Sonucu gösterme
grouped_df
# Out:
#   Product_Code                        Product_Name  Target_First_Period  \
# 0     #0200006  ADN_OPTIMUM_AVM,KZK,VALE,NEW_BLACK                   10
#
#    Target_Second_Period
# 0                    14

# %%
total_target_first_period = grouped_df['Target_First_Period'].sum()
total_target_second_period = grouped_df['Target_Second_Period'].sum()
print("1. Periyotta Gereken KZK,VALE,NEW_BLACK Sayısı:", total_target_first_period)
print("2. Periyotta Gereken KZK,VALE,NEW_BLACK Sayısı:", total_target_second_period)
# Out:
# 1. Periyotta Gereken KZK,VALE,NEW_BLACK Sayısı: 10
# 2. Periyotta Gereken KZK,VALE,NEW_BLACK Sayısı: 14

# %%
import pandas as pd

# 'expanded_df' adında mevcut bir dataframe'in olduğunu varsayıyoruz
# expanded_df'in Excel dosyasına kaydedilmesi

expanded_df.to_excel('output.xlsx', index=False)

# Google Colab'den dosyayı indirmek için
from google.colab import files
files.download('output.xlsx')

# %%
import pandas as pd

# 'expanded_df' adında mevcut bir dataframe'in olduğunu varsayıyoruz
# expanded_df'in Excel dosyasına kaydedilmesi

final_result.to_excel('output_Atlet.xlsx', index=False)

# Google Colab'den dosyayı indirmek için
from google.colab import files
files.download('output_Atlet.xlsx')
